# %%
import pandas as pd
import numpy as np

from scipy import stats
from scipy.stats import boxcox

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
file_to_open = "C:/Users/igles/Documents/Data Science/1. advStats/Seattle_ParksnRec.csv"
Seattle_ParksnRec = pd.read_csv(file_to_open)
Seattle_ParksnRec.head()
# Out:
#   Geographic_Region  Year  of_trips_Winter  of_participants_Winter  \
# 0           Central  2005               13                     154
# 1           Central  2006               17                     229
# 2           Central  2007               17                     222
# 3           Central  2008               18                     300
# 4           Central  2009               18                     276
#
#    of_trips_Spring  of_participants_Spring  of_trips_Summer  \
# 0               18                     290               20
# 1               16                     227               19
# 2               15                     244               13
# 3               19                     335               20
# 4               23                     302               25
#
#    of_participants_Summer  of_trips_Fall  of_participants_Fall  \
# 0                     267             16                   245
# 1                     265             16                   280
# ...

# %% [markdown]
# **Seattle Winter Trips**
#
# Skew: Minor Positive, dist mostly normal
#
# Transformation: SQRT

# %%
Seattle_ParksnRec.of_trips_Winter.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_trips_Winter'])

# %%
Seattle_ParksnRec['of_trips_WinterSQRT'] = np.sqrt(Seattle_ParksnRec['of_trips_Winter'])
Seattle_ParksnRec.of_trips_WinterSQRT.hist()

# %% [markdown]
# **Winter Participation**
#
# Skew: Minor Positive
#
# Transformation: SQRT

# %%
Seattle_ParksnRec.of_participants_Winter.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_participants_Winter'])

# %%
Seattle_ParksnRec['of_participants_WinterSQRT'] = np.sqrt(Seattle_ParksnRec['of_participants_Winter'])
Seattle_ParksnRec.of_participants_WinterSQRT.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_participants_WinterSQRT'])

# %% [markdown]
# **Spring Trips**
#
# Skew: Minor Positive
#
# Transformation: SQRT

# %%
Seattle_ParksnRec.of_trips_Spring.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_trips_Spring'])

# %%
Seattle_ParksnRec['of_trips_SpringSQRT'] = np.sqrt(Seattle_ParksnRec['of_trips_Spring'])
Seattle_ParksnRec.of_trips_SpringSQRT.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_trips_SpringSQRT'])

# %% [markdown]
# **Spring Participants**
#
# Skew: Minor Positive
#
# Transformation: SQRT

# %%
Seattle_ParksnRec.of_participants_Spring.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_participants_Spring'])

# %%
Seattle_ParksnRec['of_participants_SpringSQRT'] = np.sqrt(Seattle_ParksnRec['of_participants_Spring'])
Seattle_ParksnRec.of_participants_WinterSQRT.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_participants_SpringSQRT'])

# %% [markdown]
# **Trips Summer**
#
# Skew: Major Positive
#
# Transfomation: SQRT

# %%
Seattle_ParksnRec.of_trips_Summer.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_trips_Summer'])

# %%
Seattle_ParksnRec['of_trips_SummerLOG'] = np.log(Seattle_ParksnRec['of_trips_Summer'])
Seattle_ParksnRec.dropna(inplace=True)
Seattle_ParksnRec['of_trips_SummerSQRT'] = np.sqrt(Seattle_ParksnRec['of_trips_Summer'])
Seattle_ParksnRec.of_trips_SummerSQRT.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_trips_SummerSQRT'])

# %% [markdown]
# **Summer Participants**
#
# Skew: Minor Positive
#
# Transformation: SQRT

# %%
Seattle_ParksnRec.of_participants_Summer.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_participants_Summer'])

# %%
Seattle_ParksnRec['of_participants_SummerSQRT'] = np.sqrt(Seattle_ParksnRec['of_participants_Summer'])
Seattle_ParksnRec.of_participants_SummerSQRT.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_participants_SummerSQRT'])

# %% [markdown]
# **Fall Trips**
#
# Skew: Major Positive
#
# Transformation: SQRT

# %%
Seattle_ParksnRec.of_trips_Fall.hist()

# %%
Seattle_ParksnRec['of_trips_FallSQRT'] = np.sqrt(Seattle_ParksnRec['of_trips_Fall'])
Seattle_ParksnRec.of_trips_FallSQRT.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_trips_FallSQRT'])

# %% [markdown]
# **Participants Fall**
#
# Skew: Minor Positive
#
# Transformation: SQRT

# %%
Seattle_ParksnRec.of_participants_Fall.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_participants_Fall'])

# %%
Seattle_ParksnRec['of_participants_FallSQRT'] = np.sqrt(Seattle_ParksnRec['of_participants_Fall'])
Seattle_ParksnRec.of_participants_FallSQRT.hist()

# %%
sns.distplot(Seattle_ParksnRec['of_participants_FallSQRT'])
